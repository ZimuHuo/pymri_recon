# %%
import sys
sys.path.insert(1, '../')
import numpy as np
import matplotlib.pyplot as plt
from util.fft import *
import util.simulator as simulate
import util.phantom as phantom
from util.spirit import *

# %%
data = phantom.shepp_logan(64, 4)
dataR = data[::2]
acs = simulate.acs(data, (32, 32))

# %%
recon = spirit(dataR, acs, 2)

# %%
show(ifft2c(dataR))

# %%
show((recon))
