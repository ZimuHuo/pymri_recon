# %%
import sys
sys.path.insert(1, '../')
import numpy as np
import matplotlib.pyplot as plt
import util.registration as register

# %%
x = np.asarray([[40,88], [51,88],[35,78],[36,75],[39,72],[44,71],[48,71],[52,74],[55,77]])
y = np.asarray([[36,43], [48,42],[31,26],[33,28],[37,30],[40,31],[45,30],[48,28],[51,24]])

# %%
plt.scatter(x[:,0],x[:,1])
plt.scatter(y[:,0],y[:,1])
plt.show()

# %%
d, Z, t = register.procrustes(x, y, scaling=True, reflection='best')

# %%
plt.scatter(x[:,0],x[:,1])
plt.scatter(Z[:,0],Z[:,1])
plt.show()
