# %%
import sys
sys.path.insert(1, '../')
import numpy as np
import matplotlib.pyplot as plt
import util.phantom as phantom
import scipy
from scipy import ndimage
import cv2

# %%
im = np.abs(phantom.brain(256))

# %%
im = np.uint8(im)

# %%
edges = cv2.Canny(im, 100, 200, 3, L2gradient=True)

# %%
plt.imshow(edges , cmap = "gray")
