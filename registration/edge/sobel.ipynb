# %%
import sys
sys.path.insert(1, '../')
import numpy as np
import matplotlib.pyplot as plt
import util.phantom as phantom
from scipy import ndimage

# %%
im = np.abs(phantom.brain(256))

# %%
[ny, nx] = im.shape
newhorizontalImage = np.zeros((ny, nx))
newverticalImage = np.zeros((ny, nx))
newgradientImage = np.zeros((ny, nx))
horizontal = np.array([[-1, 0, 1], [-2, 0, 2], [-1, 0, 1]])  # s2
vertical = np.array([[-1, -2, -1], [0, 0, 0], [1, 2, 1]])  # s1

# %%
gn = scipy.ndimage.convolve(im, horizontal, mode='constant', cval=0.0)
gm = scipy.ndimage.convolve(im, vertical, mode='constant', cval=0.0)
mag = np.sqrt(gn**2+gm**2)

# %%
plt.imshow(mag)
